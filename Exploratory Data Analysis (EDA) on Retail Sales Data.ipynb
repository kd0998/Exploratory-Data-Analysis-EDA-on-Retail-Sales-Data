# %%
# Importing the required libraries 
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
# path of the data set
df = pd.read_csv(r"C:\Users\kadah\Desktop\retail_sales_dataset.csv")

# %% [markdown]
# # Data Loading and Cleaning: Load the retail sales dataset.

# %%
# loading the data set
df
# Out:
#      Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 0                 1  2023-11-24     CUST001    Male   34           Beauty
# 1                 2  2023-02-27     CUST002  Female   26         Clothing
# 2                 3  2023-01-13     CUST003    Male   50      Electronics
# 3                 4  2023-05-21     CUST004    Male   37         Clothing
# 4                 5  2023-05-06     CUST005    Male   30           Beauty
# ..              ...         ...         ...     ...  ...              ...
# 995             996  2023-05-16     CUST996    Male   62         Clothing
# 996             997  2023-11-17     CUST997    Male   52           Beauty
# 997             998  2023-10-29     CUST998  Female   23           Beauty
# 998             999  2023-12-05     CUST999  Female   36      Electronics
# 999            1000  2023-04-12    CUST1000    Male   47      Electronics
#
#      Quantity  Price per Unit  Total Amount
# ...

# %%
# geting top 5 rows 
df.head()
# Out:
#    Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 0               1  2023-11-24     CUST001    Male   34           Beauty
# 1               2  2023-02-27     CUST002  Female   26         Clothing
# 2               3  2023-01-13     CUST003    Male   50      Electronics
# 3               4  2023-05-21     CUST004    Male   37         Clothing
# 4               5  2023-05-06     CUST005    Male   30           Beauty
#
#    Quantity  Price per Unit  Total Amount
# 0         3              50           150
# 1         2             500          1000
# 2         1              30            30
# 3         1             500           500
# 4         2              50           100

# %%
# getting bottom 5 rows
df.tail()
# Out:
#      Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 995             996  2023-05-16     CUST996    Male   62         Clothing
# 996             997  2023-11-17     CUST997    Male   52           Beauty
# 997             998  2023-10-29     CUST998  Female   23           Beauty
# 998             999  2023-12-05     CUST999  Female   36      Electronics
# 999            1000  2023-04-12    CUST1000    Male   47      Electronics
#
#      Quantity  Price per Unit  Total Amount
# 995         1              50            50
# 996         3              30            90
# 997         4              25           100
# 998         3              50           150
# 999         4              30           120

# %%
# total shape of the data set
df.shape
# Out:
# (1000, 9)

# %%
# Data set info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    1000 non-null   int64
#  1   Date              1000 non-null   object
#  2   Customer ID       1000 non-null   object
#  3   Gender            1000 non-null   object
#  4   Age               1000 non-null   int64
#  5   Product Category  1000 non-null   object
#  6   Quantity          1000 non-null   int64
#  7   Price per Unit    1000 non-null   int64
#  8   Total Amount      1000 non-null   int64
# dtypes: int64(5), object(4)
# memory usage: 70.4+ KB

# %% [markdown]
# # Descriptive Statistics: Calculate basic statistics (mean, median, mode, standard deviation).

# %%
# Getting mean, min , max, & std
df.describe()
# Out:
#        Transaction ID         Age     Quantity  Price per Unit  Total Amount
# count     1000.000000  1000.00000  1000.000000     1000.000000   1000.000000
# mean       500.500000    41.39200     2.514000      179.890000    456.000000
# std        288.819436    13.68143     1.132734      189.681356    559.997632
# min          1.000000    18.00000     1.000000       25.000000     25.000000
# 25%        250.750000    29.00000     1.000000       30.000000     60.000000
# 50%        500.500000    42.00000     3.000000       50.000000    135.000000
# 75%        750.250000    53.00000     4.000000      300.000000    900.000000
# max       1000.000000    64.00000     4.000000      500.000000   2000.000000

# %%
# checking is there any null value present or not
df.isnull().sum()
# Out:
# Transaction ID      0
# Date                0
# Customer ID         0
# Gender              0
# Age                 0
# Product Category    0
# Quantity            0
# Price per Unit      0
# Total Amount        0
# dtype: int64

# %%
# checking null values in percentage
(df.isnull().sum() / len(df)) * 100
# Out:
# Transaction ID      0.0
# Date                0.0
# Customer ID         0.0
# Gender              0.0
# Age                 0.0
# Product Category    0.0
# Quantity            0.0
# Price per Unit      0.0
# Total Amount        0.0
# dtype: float64

# %% [markdown]
# # Visualization: Present insights through bar charts, line plots, and heatmaps.

# %%
#Visualization of null values using the heatmap

sns.heatmap(df.isnull(),yticklabels=False,cmap="inferno")
# Out:
# <Axes: >

# %%
sns.pairplot(df)

# %%
sns.scatterplot(df.Age)
# Out:
# <Axes: ylabel='Age'>

# %%
a = df.Quantity.value_counts()

# %%
plt.pie(a,wedgeprops=dict(width=0.3),autopct="%.2f%%");
plt.show()

# %%
c=df.groupby("Gender")["Gender"].count()

# %%
plt.pie(c,labels=c.index,autopct="%.2f%%")
plt.show()

# %%
plt.figure(figsize=(15,8))
plt.title("Product by Age")
plt.xlabel('Age')
plt.ylabel('Product Category')
plt.hist(df.Age, bins = np.arange(8,60,2), color = 'red', edgecolor = 'green');

# %%
e=df.groupby("Product Category")["Product Category"].count()

# %%
plt.pie(e,labels=e.index,autopct="%.2f%%")
plt.show()

# %%
plt.figure(figsize=(6,6))
sns.distplot(df['Age'])
plt.show()

# %%
sns.violinplot(x="Gender",y="Age",data=df)
plt.xticks(rotation=90)
plt.show()

# %%
sns.barplot(x='Product Category', y='Age',data=df, orient='v')
plt.xticks(rotation=90)
plt.show()

# %%
sns.kdeplot(x='Quantity', data=df)
# Out:
# <Axes: xlabel='Quantity', ylabel='Density'>

# %%
plt.figure(figsize=(6,6))
sns.boxplot(df)
plt.xticks(rotation=90)
plt.show()
